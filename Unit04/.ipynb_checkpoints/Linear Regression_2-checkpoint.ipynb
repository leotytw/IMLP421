# %% [markdown]
# # Linear Regression

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2.  線性迴歸訓練資料、測試資料
#
# 80%  training data, 20%  testing data ==> 先利用此來驗證各種模型(演算法)的好壞及調好到最佳參數
# 之後可以利用由這個80%的訓練資料所得的模型後,拿100%資料re-train模型以得到最佳模型 (此model會更佳fit data)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x = np.linspace(0, 5, 50)
y = 1.2*x + 0.8 + 0.6*np.random.randn(50)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=20)
print(x_train)
# Out:
# [4.08163265 1.73469388 1.83673469 0.         2.75510204 3.36734694
#  3.67346939 4.28571429 1.02040816 0.30612245 4.18367347 1.32653061
#  4.69387755 0.20408163 3.87755102 3.97959184 0.51020408 4.3877551
#  3.7755102  3.06122449 0.6122449  2.95918367 1.63265306 1.93877551
#  5.         4.48979592 2.14285714 3.26530612 3.46938776 0.71428571
#  2.24489796 1.12244898 2.04081633 0.91836735 4.89795918 2.85714286
#  3.16326531 1.53061224 2.65306122 3.57142857]

# %%
y
# Out:
# array([1.45299287, 0.57723507, 0.22837772, 0.95433214, 0.95279749,
#        1.90393943, 1.58116277, 2.14387574, 1.73955298, 0.59649929,
#        1.83969841, 2.57171175, 1.95496611, 1.6957606 , 1.58520724,
#        1.89185936, 1.83796244, 2.87089507, 3.34706817, 2.82639068,
#        2.84320207, 2.60606865, 3.9973829 , 3.69531733, 3.29935518,
#        3.27701914, 4.86527163, 3.94351352, 5.01830278, 4.12732194,
#        5.34332826, 5.38518911, 4.15558208, 5.40001926, 5.09274782,
#        5.13032028, 5.41896077, 4.83929048, 6.00248302, 5.01268359,
#        5.55476511, 5.94464146, 6.37713635, 6.21821882, 5.84282676,
#        6.78182667, 6.21628558, 6.52398233, 5.72657499, 7.84065289])

# %%
plt.scatter(x_train, y_train)

# %% [markdown]
# #### 用訓練資料來 fit 函數
#
# 記得現在我們只用 80% 的資料去訓練。

# %%
regr = LinearRegression()
X_train = x_train.reshape(-1,1)
regr.fit(X_train,y_train)
print('Coefficients: ', regr.coef_)
print('interception: ', regr.intercept_)
# Out:
# Coefficients:  [1.25406517]
# interception:  0.6466053716389055

# %%
Y_train = regr.predict(X_train)

# %%
mse = np.sum((Y_train-y_train)**2) / len(y_train)
print(mse)
# Out:
# 0.3300327356751883

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train, Y_train, 'r')

# %% [markdown]
# #### test with test data

# %%
X_test = x_test.reshape(-1,1)
Y_test = regr.predict(X_test)

print(Y_test)
# Out:
# [2.18219537 2.43812704 1.15846871 1.67033204 6.40506788 0.77457121
#  3.84575121 3.71778537 6.66099954 3.58981954]

# %% [markdown]
# $$\widehat{y}=xw+b=w_{1}x_{1}+b$$

# %%
#Y=WX+b
W=regr.coef_
b=regr.intercept_
W*X_test+b
# Out:
# array([[2.18219537],
#        [2.43812704],
#        [1.15846871],
#        [1.67033204],
#        [6.40506788],
#        [0.77457121],
#        [3.84575121],
#        [3.71778537],
#        [6.66099954],
#        [3.58981954]])

# %%
mse = np.sum((Y_test-y_test)**2) / len(y_test)
print(mse)
# Out:
# 0.15355297326508738

# %%
title='f(x)=1.2x+0.8'+',mse:'+str(round(mse,2))
plt.title(title)
plt.xlabel('x')
plt.ylabel('y')
#plt.grid(True)
plt.scatter(x_test, y_test,alpha=0.8,label='Ground Truth')
plt.scatter(x_test, Y_test, c='r', alpha=0.8,label='Predict')
plt.legend()
