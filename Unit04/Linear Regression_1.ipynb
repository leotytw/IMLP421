# %% [markdown]
# # Linear Regression

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. 線性迴歸基本概念

# %% [markdown]
# #### 直線
#
# $$f(x) = 1.2x + 0.8$$

# %%
#準備 50 個點
#5-0/50 = 0.1 +....
# 0~5線性切割
x = np.linspace(0, 5, 50)
print(x)
# Out:
# [0.         0.10204082 0.20408163 0.30612245 0.40816327 0.51020408
#  0.6122449  0.71428571 0.81632653 0.91836735 1.02040816 1.12244898
#  1.2244898  1.32653061 1.42857143 1.53061224 1.63265306 1.73469388
#  1.83673469 1.93877551 2.04081633 2.14285714 2.24489796 2.34693878
#  2.44897959 2.55102041 2.65306122 2.75510204 2.85714286 2.95918367
#  3.06122449 3.16326531 3.26530612 3.36734694 3.46938776 3.57142857
#  3.67346939 3.7755102  3.87755102 3.97959184 4.08163265 4.18367347
#  4.28571429 4.3877551  4.48979592 4.59183673 4.69387755 4.79591837
#  4.89795918 5.        ]

# %%
y = 1.2*x + 0.8
y
# Out:
# array([0.8       , 0.92244898, 1.04489796, 1.16734694, 1.28979592,
#        1.4122449 , 1.53469388, 1.65714286, 1.77959184, 1.90204082,
#        2.0244898 , 2.14693878, 2.26938776, 2.39183673, 2.51428571,
#        2.63673469, 2.75918367, 2.88163265, 3.00408163, 3.12653061,
#        3.24897959, 3.37142857, 3.49387755, 3.61632653, 3.73877551,
#        3.86122449, 3.98367347, 4.10612245, 4.22857143, 4.35102041,
#        4.47346939, 4.59591837, 4.71836735, 4.84081633, 4.96326531,
#        5.08571429, 5.20816327, 5.33061224, 5.45306122, 5.5755102 ,
#        5.69795918, 5.82040816, 5.94285714, 6.06530612, 6.1877551 ,
#        6.31020408, 6.43265306, 6.55510204, 6.67755102, 6.8       ])

# %%
#畫圖
plt.scatter(x,y)
plt.plot(x, 1.2*x+0.8, 'r')

# %% [markdown]
# #### add noise
#
# $$f(x) + \varepsilon(x)$$

# %%
y = 1.2*x + 0.8 + 0.6*np.random.randn(50)
print(y)
# Out:
# [0.154237   1.06994326 0.89447972 1.45755887 1.3874123  1.39390035
#  0.72262748 1.76555899 2.01755524 1.99738446 2.53416523 2.29575716
#  2.35392191 2.37134354 2.87229484 1.578953   2.73504202 1.95560783
#  3.95549264 3.15389941 2.97511916 2.6099928  3.72935158 3.97160681
#  3.98482353 3.46196931 3.3013661  4.23943043 4.61706323 3.4380254
#  4.32280823 4.40483441 4.40060256 3.99511573 4.69393123 5.62997524
#  5.23483992 5.09773778 6.19034643 5.03917349 5.76058431 5.85953044
#  5.58150385 5.37492825 6.11461155 6.60802119 5.96413662 6.79811623
#  6.1463668  6.70440441]

# %%
plt.scatter(x,y)
plt.plot(x, 1.2*x + 0.8, 'r')

# %%
from sklearn.linear_model import LinearRegression
regr = LinearRegression()

# %%
params = regr.get_params()
print(params)
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %% [markdown]
# 要求資料轉換<br>
#
# $$[x_1, x_2, \ldots, x_{50}]$$
#
# ==>
#
# $$[[x_1], [x_2], \ldots, [x_{50}]]$$
#
#
# 矩陣的概念

# %%
print(x.shape)
X = x.reshape(-1,1)
X.shape
# Out:
# (50,)
# (50, 1)

# %%
regr.fit(X,y)
# Out:
# LinearRegression()

# %%
Y = regr.predict(X)
print(Y)
# Out:
# [0.768154   0.88775379 1.00735359 1.12695339 1.24655319 1.36615299
#  1.48575278 1.60535258 1.72495238 1.84455218 1.96415198 2.08375177
#  2.20335157 2.32295137 2.44255117 2.56215096 2.68175076 2.80135056
#  2.92095036 3.04055016 3.16014995 3.27974975 3.39934955 3.51894935
#  3.63854915 3.75814894 3.87774874 3.99734854 4.11694834 4.23654814
#  4.35614793 4.47574773 4.59534753 4.71494733 4.83454713 4.95414692
#  5.07374672 5.19334652 5.31294632 5.43254612 5.55214591 5.67174571
#  5.79134551 5.91094531 6.03054511 6.1501449  6.2697447  6.3893445
#  6.5089443  6.6285441 ]

# %%
#了解你的訓練參數
regr.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
plt.scatter(x, y) #原本 
plt.plot(x, Y, 'ro') #預測
#calculate mse
mse = np.sum((Y-y)**2) / len(y)
print(mse)
# Out:
# 0.19845839720496006

# %%
#Y=WX+b
W=regr.coef_#斜率
W
# Out:
# array([1.17207802])

# %%
b=regr.intercept_ #截距
b
# Out:
# 0.7681539956685057

# %%
Y
# Out:
# array([0.768154  , 0.88775379, 1.00735359, 1.12695339, 1.24655319,
#        1.36615299, 1.48575278, 1.60535258, 1.72495238, 1.84455218,
#        1.96415198, 2.08375177, 2.20335157, 2.32295137, 2.44255117,
#        2.56215096, 2.68175076, 2.80135056, 2.92095036, 3.04055016,
#        3.16014995, 3.27974975, 3.39934955, 3.51894935, 3.63854915,
#        3.75814894, 3.87774874, 3.99734854, 4.11694834, 4.23654814,
#        4.35614793, 4.47574773, 4.59534753, 4.71494733, 4.83454713,
#        4.95414692, 5.07374672, 5.19334652, 5.31294632, 5.43254612,
#        5.55214591, 5.67174571, 5.79134551, 5.91094531, 6.03054511,
#        6.1501449 , 6.2697447 , 6.3893445 , 6.5089443 , 6.6285441 ])

# %%
#可以將新的x資料帶入算出結果
W*3+b
# Out:
# array([4.28438806])

# %%
y
# Out:
# array([0.154237  , 1.06994326, 0.89447972, 1.45755887, 1.3874123 ,
#        1.39390035, 0.72262748, 1.76555899, 2.01755524, 1.99738446,
#        2.53416523, 2.29575716, 2.35392191, 2.37134354, 2.87229484,
#        1.578953  , 2.73504202, 1.95560783, 3.95549264, 3.15389941,
#        2.97511916, 2.6099928 , 3.72935158, 3.97160681, 3.98482353,
#        3.46196931, 3.3013661 , 4.23943043, 4.61706323, 3.4380254 ,
#        4.32280823, 4.40483441, 4.40060256, 3.99511573, 4.69393123,
#        5.62997524, 5.23483992, 5.09773778, 6.19034643, 5.03917349,
#        5.76058431, 5.85953044, 5.58150385, 5.37492825, 6.11461155,
#        6.60802119, 5.96413662, 6.79811623, 6.1463668 , 6.70440441])
